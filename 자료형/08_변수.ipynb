# %%
# 변수는 어떻게 만들까?
a = 1
b = "python"
c = [1, 2, 3]

# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용 가능
a1 = 1
t1 = 2
type_script = 1
typeScript = 1
import builtins
# 2. 숫자로 시작 불가능
t1 = 1
# 1t = 1 <- 사용 불가능

# 3. 예약어 불가능 (파이썬에 지정된 이름 - print, len, False, and, if, import)
#print - <- 1로 지정된 상태라 다른 함수 출력 불가능

# 4. 대소문자 구분
Abc = 1
abc = 2
print(Abc)
print(abc)

a, b = ("python", "Life")
print(a)
print(b)
[a, b] = ["python", "Life"] # 리스트 형식
print(a)
print(b)
# Out:
# 1
# 2
# python
# Life
# python
# Life

# %%
# 속성 복구 방법
import builtins
print = builtins.print
