# %%
# 튜플은 어떻게 만들까?
t1 = ()
t2 = (1, ) 뒤에 ,가 있어야 튜플이라는 것 인식 가능
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ("a", "b", ("ab", "cd")) 튜플 안에 튜플

a

# %%
t1 = (1, 2, "a", "b")

# 튜플 요소 값을 삭제하려 할 때 -> 삭제 불가능
del t1[0]

# %%
t1 = (1, 2, "a", "b")

# 튜플 요소값을 변경하려 할때 -> 변경할 수 없음
t1[1] = 4

# %%
# 인덱싱 하기
t1 = (1, 2, "a", "b")
t1[2]
# Out:
# 'a'

# %%
# 슬라이싱 하기
t1 = (1, 2, "a", "b")
t1[2:4]
# Out:
# ('a', 'b')

# %%
# 튜플 더하기
t1 = (1, 2, "a", "b")
t2 = (3, 4)
t1 + t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
# 튜플 곱하기
t2 = (3, 4)
t2 * 3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
# 튜플 길이 구하기
t1 = (1, 2, "a", "b")
len(t1)
# Out:
# 4
