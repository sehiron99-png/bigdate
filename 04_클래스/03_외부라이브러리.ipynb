# %%
# pip install (설치된 라이브러리에 가능한 모듈 설치에 대한 매서드)
# pypi (pip 저장하는 것파이썬 소프트웨어가 모인 저장 공간)
# !pip install SomePackage

# %%
# pip install 패키지명 - 설치
# pip uninstall 패키지명 - 삭제
# pip install 패키지명==버전 - 특정 버전 설치
# pip list - 설치된 패키지 리스트 확인

# %%
# !pip install Faker

# %%
from faker import Faker # class명은 항상 대문자

fake = Faker() # 객체 설정
fake.name() # 가짜 이름 나옴
fake.address() # 가짜 주소

for _ in range(10):
    print(fake.name())
# Out:
# Marcia Davis
# David Murphy
# Rick Watson
# Chloe Walker
# Michelle Fitzgerald
# Raymond Briggs
# Marie Bullock
# Angela Pitts
# Rebekah Harris
# Summer Robinson

# %%
import faker
a = faker.Faker()
a.name()
# Out:
# 'Patricia Guzman'
